# %% [markdown]
# # <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:120%; text-align:center; border-radius:1000px 1000px;">• Capstone Project | Water Potability Prediction •</p>

# %% [markdown]
# <image src="https://github.com/MilanVirash/Study_BIA/blob/main/Image.jpg?raw=true" width="1500">

# %% [markdown]
# <div style="background-color: #2E2222; padding: 25px; border-radius:50px 50px; width:94%;">
#     <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:230%; text-align:left; border-radius:0px 0px;">• About The Project</p>
#     <p style="font-family: 'Book Antiqua'; color: white; font-size:130%">• In this project, the aim is to develop a machine learning model to predict water potability based on various water quality parameters. This model will help in assessing whether water is safe for consumption, which is crucial for public health and water management.  Access to clean drinking water is a global challenge, with millions of people lacking reliable sources of potable water. By developing advanced predictive models, we can contribute to global efforts in improving water quality and ensuring safe drinking water for communities worldwide.</p>
#     <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:230%; text-align:left; border-radius:0px 0px;">• Question</p>
#     <h3 style="font-family: 'Book Antiqua'; color: white;">• Is the water potable or not?</h3>
# </div>

# %% [markdown]
# <div style="background-color: #2E2222; padding: 25px; border-radius:50px 50px; width:70%;">
#
# <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:230%; text-align:left; border-radius:0px 0px;">• Objectives</p>
#
# <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:230%; text-align:left; border-radius:0px 0px;">
#
# * __Explore the Dataset__: Uncover patterns, distributions, and relationships within the data.
# * __Conduct Extensive Exploratory Data Analysis (EDA)__: Dive deep into univariate and bivariate relationships against the target.
# * __Preprocessing Steps__:
#   - Remove irrelevant features
#   - Address missing values
#   - Treat outliers
#   - Encode categorical variables
#   - Transform skewed features to achieve normal-like distributions
# * __Model Building__:
#   - Establish models
#   - Implement and tune classification models including Logistic Regression, SVM, Decision Trees, Random Forest and KNN
#   - Emphasize achieving high recall for class 1, ensuring comprehensive identification potability
# * __Evaluate and Compare Model Performance__: Utilize precision, recall, and F1-score to gauge models' effectiveness.
# </p>

# %% [markdown]
# <div style="background-color: #2E2222; padding: 25px; border-radius:50px 50px; width:30%;">
#     <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:230%; text-align:left; border-radius:0px 0px;">• Table Of Contents:</p>
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Project Steps</title>
#     <style>
#         body {
#             background-color: #9c9898;
#             color: black;
#             font-family: Arial, sans-serif;
#         }
#         .content {
#             font-size: 20px; /* Adjust the font size as needed */
#             font-family: 'Arial Bold', serif; /* Change the font style as needed */
#             color:white;
#         }
#         h1, h2, h3, h4, h5, h6 {
#             font-size: 0px; /* Adjust the font size for all headings */
#         }
#     </style>
# </head>
# <body>
#
# <div class="content">
#     <ol>
#         <li><strong>Import Libraries</strong>
#         </li>
#         <li><strong>Read Dataset</strong>
#             <ul>
#                 <li>Load The Dataset</li>
#                 <li>Dataset Discription</li>
#             </ul>
#         </li>
#         <li><strong>Dataset Overview</strong>
#             <ul>
#                 <li>Basic Information</li>
#                 <li>Statistic Summary</li>
#             </ul>
#         </li>
#         <li><strong>EDA</strong></li>
#             <ul>
#                 <li>Univariate Analysis</li>
#                 <li>Distribution Of Target Variable</li>
#                 <li>Bivariate Analysis</li>
#                 <li>Checking Outliears</li>
#             </ul>
#         <li><strong>Data PreProcessing</strong>
#             <ul>
#                 <li>Missing Values Treatment</li>
#                 <li>Outlier Removal</li>
#                 <li>Data Splitting & Standardization</li>
#             </ul>
#         </li>
#         <li><strong>Logistic Regression</strong></li>
#             <ul>
#                 <li>LR Base Model</li>
#                 <li>LR Hyperparameter Tuning</li>
#                 <li>LR Model Evaluation</li>
#             </ul>
#         </li>
#         <li><strong>Decision Tree</strong></li>
#             <ul>
#                 <li>DT Base Model</li>
#                 <li>DT Hyperparameter Tuning</li>
#                 <li>DT Model Evaluation</li>
#             </ul>
#         </li>
#         <li><strong>Random Forest</strong></li>
#             <ul>
#                 <li>RF Base Model</li>
#                 <li>RF Hyperparameter Tuning</li>
#                 <li>RF Model Evaluation</li>
#             </ul>
#         </li>
#         <li><strong>SVM</strong></li>
#             <ul>
#                 <li>SVN Base Model</li>
#                 <li>SVM Hyperparameter Tuning</li>
#                 <li>SVMModel Evaluation</li>
#             </ul>
#         </li>
#         <li><strong>XGBoost</strong></li>
#             <ul>
#                 <li>XGBoost Base Model</li>
#                 <li>XGBoost Model Evaluation</li>
#             </ul>
#         </li>
#         <li><strong>Comparison Of All Algorithms</strong></li>
#         <li><strong>Conclusion</strong></li>
#     </ol>
# </div>
#
# </body>
# </html>

# %% [markdown]
# # <b> Let's Get Started:

# %% [markdown]
# # <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:120%; text-align:center; border-radius:1000px 1000px;">↪  Step 1  :  Import Libraries :</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn import tree

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:120%; text-align:center; border-radius:1000px 1000px;">↪  Step 2  :  Read Dataset :</p>

# %% [markdown]
# #  <b> • Let's load the dataset:

# %%
data = pd.read_csv("water_potability.csv")
data
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %% [markdown]
# #  <b> • Dataset Discription:

# %% [markdown]
# <div style="background-color: #975455; padding: 25px; border-radius: 50px; width:80%;">
#     <p style="font-family: 'Book Antiqua'; color: white; font-size:130%">• All the columns given in the dataset are water components. Which I have tried to briefly introduce here in the table.</p>
#     <table style="width: 95%; background-color: #dbdbd9; border: 3px solid black; color: black; border-collapse: collapse;">
#         <tr>
#             <th style="border: 3px solid black; padding: 8px; font-family: 'Verdana';">Parameter</th>
#             <th style="border: 3px solid black; padding: 8px; font-family: 'Verdana';">Meaning</th>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">pH value</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Indicates the acidity or alkalinity of water; standard range is 6.5 to 8.5.</td>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Hardness</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Measures the concentration of calcium and magnesium salts; no specific standard, but generally measured in mg/L.</td>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Solids (Total dissolved solids - TDS)</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Measures dissolved minerals in water; desirable limit is 500 mg/L, maximum limit is 1000 mg/L.</td>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Chloramines</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Disinfectants formed by adding ammonia to chlorine; safe levels are up to 4 mg/L.</td>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Sulfate</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Naturally occurring in minerals and soil; typical range in freshwater is 3 to 30 mg/L, can be higher in some areas.</td>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Conductivity</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Measures water’s ability to conduct electricity; WHO standard is not to exceed 400 μS/cm.</td>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Organic Carbon</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Total amount of carbon in organic compounds; US EPA standard is < 2 mg/L in treated water, < 4 mg/L in source water.</td>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Trihalomethanes</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Byproducts of chlorination; safe levels are up to 80 ppm.</td>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Turbidity</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Measures the clarity of water; WHO recommended value is below 5 NTU.</td>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Potability</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Indicates if water is safe for consumption; 1 means potable, 0 means not potable.</td>
#         </tr>
#     </table>
# </div>

# %% [markdown]
# # <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:120%; text-align:center; border-radius:1000px 1000px;">↪  Step 3  :  Dataset Overview :</p>

# %% [markdown]
# #  <b> • Dataset Basic Information:

# %%
data.shape
# Out:
# (3276, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
data.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #975455; font-size:115%; text-align:left; width: 50%; ">
#
# <h2 align="left"><font color="White" style="font-family: 'Book Antiqua';">Inferences:</font></h2>
#
# <p align="left"><font color="White" style="font-family: 'Book Antiqua';">
#
# * __Number of Rows and Columns:__
#     - The dataset contains __3276__ rows and __10__ columns.
#
#
# * __Data Types:__
#     - 9 columns of type float64
#     - 1 column of type int64(Target Column: Potability)
#
#
# * __Missing Values:__
#     - ph: __491__ missing values
#     - Sulfate: __781__ missing values
#     - Trihalomethanes: __162__ missing values
#     - The remaining columns (Hardness, Solids, Chloramines, Conductivity, Organic_carbon, Turbidity, Potability) have no missing values.
#
# * __Target Variable:__
#     - Target Column: Potability
#     - __0__ Means __Not Potable__
#     - __1__ means __Potable__
# </p>

# %% [markdown]
# #  <b> • Statistics Summary

# %%
data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %% [markdown]
# # <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:120%; text-align:center; border-radius:1000px 1000px;">↪  Step 4  :  EDA :</p>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #975455; font-size:115%; text-align:left; width: 70%;">
# <p align="left"><font color="White" style="font-family: 'Book Antiqua';">
# For our __Exploratory Data Analysis (EDA)__, we'll take it in two main steps:
#
# * __1. Univariate Analysis:__:
#     - Here, we'll focus on one feature at a time to understand its distribution and range.
#
#
# * __2. Bivariate Analysis:__:
#     - In this step, we'll explore the relationship between each feature and the target variable. This helps us figure out the importance and influence of each feature on the target outcome.
#
# With these two steps, we aim to gain insights into the individual characteristics of the data and also how each feature relates to our main goal: __predicting the target variable__.
# </font></p>

# %% [markdown]
# #  <b> • Univariate Analysis:

# %%
fig, axes = plt.subplots(4, 3, figsize=(15, 10), facecolor='#6b5c5c')

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Loop through each column in the DataFrame
for i, col in enumerate(data.columns):
    sns.histplot(data[col], kde=True, ax=axes[i], color='red', bins=20)  # Reduce the number of bins to 20
    axes[i].grid(True)  # Add grid

# Remove any unused subplots
for j in range(len(data.columns), len(axes)):
    fig.delaxes(axes[j])

# Add main title
fig.suptitle('Distribution Of Variables', fontsize=26, color="white", font="Book Antiqua")

for ax in axes:
    ax.set_xlabel(ax.get_xlabel(), color='white', fontsize=15)
    ax.set_ylabel(ax.get_ylabel(), color='white', fontsize=15)

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to make room for the title
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #975455; font-size:115%; text-align:left; width: 95%; ">
#
# <h2 align="left"><font color="White" style="font-family: 'Book Antiqua';">Inferences:</font></h2>
#
# <p align="left"><font color="White" style="font-family: 'Book Antiqua';">
#
# - __All features have a very similar distribution of their values.__
# - __In addition, they all show a very gaussian form so there is no need to normalize any feature.__
# - __However here I have applied some algorithms which require normalization or standardization so I have standardize the data further.__
# </font></p>

# %% [markdown]
# # <b> • Count Plot Of Target Variable:

# %%
countt = data['Potability'].value_counts()
countt
# Out:
# Potability
# 0    1998
# 1    1278
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5, 4))
plt.title("Distribution Of Target Column")
plt.bar(countt.index, countt.values, color=['#ff9999','#66b3ff'], label=['Not Potable', 'Potable'])
plt.xticks(range(len(countt)), countt.index)
plt.legend()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #975455; font-size:115%; text-align:left; width: 95%; ">
#
# <h2 align="left"><font color="White" style="font-family: 'Book Antiqua';">Inferences:</font></h2>
#
# <p align="left"><font color="White" style="font-family: 'Book Antiqua';">
# Explanation
# Visualization Purpose: The plot shows the count of each class (0 = Not Potable, 1 = Potable) in the dataset, allowing you to quickly assess whether the classes are balanced or imbalanced.
# </font></p>

# %% [markdown]
# #  <b> • Bivariate Analysis:

# %%
plt.figure(figsize=(15, 6))
plt.title("Correlation Of Attributes", y=1.05, size=19)
sns.heatmap(data.corr(), annot=True, cmap='Oranges')
plt.show()

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #975455; font-size:115%; text-align:left; width: 95%; ">
#
# <h2 align="left"><font color="White" style="font-family: 'Book Antiqua';">Inferences:</font></h2>
#
# <p align="left"><font color="White" style="font-family: 'Book Antiqua';">
#
# * __Moderate Positive Correlation with Potability:__ No variables show a high or moderate positive correlation with Potability, indicating that none of the features strongly predict potability in a positive direction.
#
# * __Moderate Negative Correlation with Potability:__ Sulfate, Trihalomethanes, and Conductivity show moderate negative correlations with Potability, suggesting that higher levels of these factors may be associated with non-potable water.
#
# * __Less Correlation with Potability:__ Variables such as ph, Hardness, Solids, Chloramines, Organic_carbon, and Turbidity exhibit weak or negligible correlations with Potability, indicating that these factors alone do not have a strong influence on determining whether water is potable.
# </font></p>

# %% [markdown]
# #  <b> • Checking Outliers:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the figure size
plt.figure(figsize=(13, 6))

# List of colors for each boxplot
colors = ['lightblue', 'lightgreen', 'lightcoral', 'lightsalmon', 'lightseagreen',
          'lightpink', 'lightsteelblue', 'lightyellow', 'lightcyan', 'lightgray']

# Iterate over each column and create a boxplot
for i, column in enumerate(data.columns, 1):
    plt.subplot(2, 5, i)  # 2 rows, 5 columns
    sns.boxplot(data=data, y=column, color=colors[i-1])
    plt.title(f'Boxplot of {column}')

# Adjust layout
plt.suptitle("BoxPlot For Outliers Checking", fontsize=25, )
plt.grid()
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# # <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:120%; text-align:center; border-radius:1000px 1000px;">↪  Step 5  :  Data Preprocessiong :</p>

# %% [markdown]
# #  <b> • Missing Values Treatment:

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #975455; font-size:115%; text-align:left; width: 70%;">
# <p align="left"><font color="White" style="font-family: 'Book Antiqua';">
# In the __missing value treatment__, instead of removing rows with missing values, we fill them using the mean or median. Since our dataset is already small, removing rows with missing values would reduce its size even further.
#
# Therefore, I have filled the missing values with the __mean__ of each field for both categories.
# </font></p>

# %%
data.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
#calculating mean values for each field for both categories
#for sulfate
sulfate_0 = data[data['Potability']==0]['Sulfate'].mean(skipna=True)
sulfate_1 = data[data['Potability']==1]['Sulfate'].mean(skipna=True)



#for ph
ph_0 = data[data['Potability']==0]['ph'].mean(skipna=True)
ph_1 = data[data['Potability']==1]['ph'].mean(skipna=True)



#for Trihalomethanes
Trihalo_0 = data[data['Potability']==0]['Trihalomethanes'].mean(skipna=True)
Trihalo_1 = data[data['Potability']==1]['Trihalomethanes'].mean(skipna=True)

# %%
d = {'Sulfate':[sulfate_0,sulfate_1,data['Sulfate'].mean()],'ph':[ph_0,ph_1,data['ph'].mean()],
     'Trihalomethanes':[Trihalo_0,Trihalo_1,data['Trihalomethanes'].mean()]}

mean_df = pd.DataFrame(data=d,index=['Potability 0','Potability 1','Population mean'])

# %%
#sulfate mean imputation

data.loc[(data['Potability'] == 0) & (data['Sulfate'].isna()), 'Sulfate'] = sulfate_0
data.loc[(data['Potability'] == 1) & (data['Sulfate'].isna()), 'Sulfate'] = sulfate_1

# %%
#ph mean imputation

data.loc[(data['Potability'] == 0) & (data['ph'].isna()), 'ph'] = ph_0
data.loc[(data['Potability'] == 1) & (data['ph'].isna()), 'ph'] = ph_1

# %%
#Trihalomethanes mean imputation

data.loc[(data['Potability'] == 0) & (data['Trihalomethanes'].isna()), 'Trihalomethanes'] = Trihalo_0
data.loc[(data['Potability'] == 1) & (data['Trihalomethanes'].isna()), 'Trihalomethanes'] = Trihalo_1

# %%
data.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# #  <b> • Outlier Treatment:

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #975455; font-size:115%; text-align:left; width: 90%;">
# <p align="left"><font color="White" style="font-family: 'Book Antiqua';">
# In a water potability dataset, outliers could represent instances where water quality is dangerously high or low for certain contaminants. These extreme values could be crucial for identifying water sources that pose significant health risks.
#
# Removing outliers can distort the natural distribution of the data, potentially leading to misleading statistical summaries or modeling results.
#
# Some machine learning models, especially those based on decision trees (like Random Forests) or those using robust methods (like SVM with an appropriate kernel), can handle outliers effectively. Removing outliers might deprive these models of valuable information.
#
# And our dataset is already small, if we remove the outliers, it will get even smaller.
#
# So I did not remove OUTLIERS but replace it with lower/upper whiskers.
# </font></p>

# %%
# Function to replace outliers with lower/upper whiskers
def replace_outliers(data):
    for col in data.columns:
        if data[col].dtype != 'object':  # Apply only to numeric columns
            Q1 = data[col].quantile(0.25)
            Q3 = data[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_whisker = Q1 - 1.5 * IQR
            upper_whisker = Q3 + 1.5 * IQR
            
            # Replace values below the lower whisker
            data[col] = data[col].apply(lambda x: lower_whisker if x < lower_whisker else x)
            # Replace values above the upper whisker
            data[col] = data[col].apply(lambda x: upper_whisker if x > upper_whisker else x)
    return data

# Apply the function to the dataset
cleaned_data = replace_outliers(data)

# Check the result
cleaned_data.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  3276.000000  3276.000000   3276.000000  3276.000000  3276.000000
# mean      7.080009   196.392423  21957.112200     7.121794   333.798024
# std       1.381953    32.017189   8592.820397     1.544126    31.771515
# min       3.889107   117.125160    320.942611     3.146221   267.157960
# 25%       6.277673   176.850538  15666.690297     6.127421   317.094638
# 50%       7.085378   196.967627  20927.833607     7.130299   334.564290
# 75%       7.870050   216.667456  27332.762127     8.114887   350.385756
# max      10.258615   276.392834  44831.869873    11.096086   400.322434
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3276.000000  3276.000000  3276.000000
# mean     426.129974       14.283462        66.419805     3.966612     0.390110
# std       80.564144        3.288367        15.487167     0.776409     0.487849
# ...

# %% [markdown]
# #  <b> • Data Splitting And SMOTE For make the Data Balanced:

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# %%
x = data.drop('Potability', axis=1)
y = data['Potability']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=24)

# %%
from sklearn.mixture import GaussianMixture

# Fit GMM on the minority class (Potability == 1) to generate synthetic data
gmm = GaussianMixture(n_components=2, random_state=42)

# Train the GMM on the minority class data
X_minority = x_train[y_train == 1]
gmm.fit(X_minority)

# Generate synthetic samples from GMM
synthetic_data, _ = gmm.sample(n_samples=100)  # Specify the number of synthetic samples

# Create a DataFrame for the synthetic samples
synthetic_df = pd.DataFrame(synthetic_data, columns=x.columns)

# Assign the target label (Potability == 1) to the synthetic data
synthetic_labels = np.ones(synthetic_df.shape[0])

# Combine original training data with synthetic data
X_train_Smote = np.vstack([x_train, synthetic_df])
y_train_Smote = np.hstack([y_train, synthetic_labels])

# %% [markdown]
# # <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:120%; text-align:center; border-radius:1000px 1000px;">↪  Step 6  :  Logistic Regression Model Building :</p>

# %% [markdown]
# #  <b> • LR Base Model:

# %%
# Define the base LR model
LR = LogisticRegression()

# %% [markdown]
# #  <b> • LR Hyperparameter Tuning:

# %%
# Define the LR Parameter Grid
param_grid_logistic = {
    'penalty': ['l1', 'l2'],  # Regularization technique: 'l1' for Lasso (sparse solution), 'l2' for Ridge (smaller coefficients).
    'C': [0.001, 0.01, 0.1, 1, 10, 100],  # Inverse of regularization strength, with smaller values applying stronger regularization.
    'solver': ['liblinear']  # Algorithm to use for optimization, 'liblinear' is suitable for smaller datasets and supports 'l1' and 'l2' penalties.
}

# %%
gridSerch_LR = GridSearchCV(estimator=LR, param_grid=param_grid_logistic, cv=5, scoring='accuracy', n_jobs=-1)
gridSerch_LR.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'penalty': ['l1', 'l2'], 'solver': ['liblinear']},
#              scoring='accuracy')

# %%
best_params_LR = gridSerch_LR.best_params_
best_params_LR
# Out:
# {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
best_LR = LogisticRegression(random_state=42, **best_params_LR)
best_LR.fit(X_train_Smote, y_train_Smote)
# Out:
# LogisticRegression(C=10, penalty='l1', random_state=42, solver='liblinear')

# %% [markdown]
# #  <b> • LR Model Evaluation:

# %%
# Evaluate the optimized model on the train data
print(classification_report(y_train, best_LR.predict(x_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.76      1417
#            1       0.80      0.01      0.02       876
#
#     accuracy                           0.62      2293
#    macro avg       0.71      0.50      0.39      2293
# weighted avg       0.69      0.62      0.48      2293

# %%
# Evaluate the optimized model on the test data
print(classification_report(y_test, best_LR.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      1.00      0.75       581
#            1       1.00      0.01      0.02       402
#
#     accuracy                           0.60       983
#    macro avg       0.80      0.51      0.38       983
# weighted avg       0.76      0.60      0.45       983

# %%
# Confusion Metrics
confusion_LR = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, best_LR.predict(x_test)))
confusion_LR.plot()

# %% [markdown]
# # <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:120%; text-align:center; border-radius:1000px 1000px;">↪  Step 7  :  Decision Tree Model Building :</p>

# %% [markdown]
# #  <b> • DT Base Model:

# %%
# Define the base DT model
DT = DecisionTreeClassifier(random_state=0)

# %% [markdown]
# #  <b> • DT Hyperparameter Tuning:

# %%
# Define the DT hyperparameter
param_grid_dt = {
    'criterion': ['gini', 'entropy'],  # Function to measure the quality of a split.
    'max_depth': [2, 3],  # Maximum depth of the tree.
    'min_samples_split': [2, 3, 4],  # Minimum samples required to split a node.
    'min_samples_leaf': [1, 2]  # Minimum samples required to be a leaf node.
}

# %%
gridSearch_DT = GridSearchCV(estimator=DT, param_grid=param_grid_dt, cv=5, scoring='accuracy', n_jobs=-1)
gridSearch_DT.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=0), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [2, 3],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 3, 4]},
#              scoring='accuracy')

# %%
best_params_DT = gridSearch_DT.best_params_
best_params_DT
# Out:
# {'criterion': 'entropy',
#  'max_depth': 3,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2}

# %%
best_DT = DecisionTreeClassifier(random_state=42, **best_params_DT)
best_DT.fit(X_train_Smote, y_train_Smote)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=42)

# %%
# Visualize the decision tree

plt.figure(figsize=(10, 7))
tree.plot_tree(best_DT, filled=True)
plt.show()

# %% [markdown]
# #  <b> • DT Model Evaluation:

# %%
# Evaluate the optimized model on the train data
print(classification_report(y_train, best_DT.predict(x_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.88      0.79      1417
#            1       0.69      0.46      0.55       876
#
#     accuracy                           0.72      2293
#    macro avg       0.71      0.67      0.67      2293
# weighted avg       0.71      0.72      0.70      2293

# %%
# Evaluate the optimized model on the test data
print(classification_report(y_test, best_DT.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.86      0.79       581
#            1       0.73      0.53      0.61       402
#
#     accuracy                           0.73       983
#    macro avg       0.73      0.70      0.70       983
# weighted avg       0.73      0.73      0.72       983

# %%
# Confusion Metrics
confusion_DT = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, best_DT.predict(x_test)))
confusion_DT.plot()

# %% [markdown]
# # <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:120%; text-align:center; border-radius:1000px 1000px;">↪  Step 8  :  Random Forest Model Building :</p>

# %% [markdown]
# #  <b> • RF Base Model:

# %%
# Define the base RF model
base_RF = RandomForestClassifier(random_state=0)

# %% [markdown]
# #  <b> • RF Hyperparameter Tuning:

# %%
# Define the RF hyperparameter 
param_grid_RF = {
    'n_estimators': [10, 30, 50],  # Number of trees in the forest.
    'criterion': ['gini', 'entropy'],  # Function to measure split quality.
    'max_depth': [2, 3, 4],  # Maximum depth of each tree.
    'min_samples_split': [2, 3, 4, 5],  # Minimum samples required to split a node.
    'min_samples_leaf': [1, 2, 3],  # Minimum samples required to be a leaf node.
    'bootstrap': [True, False]  # Whether to use bootstrap samples.
}

# %%
gridSearch_RF = GridSearchCV(estimator=base_RF, param_grid=param_grid_RF, cv=5, scoring='accuracy', n_jobs=-1)
gridSearch_RF.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=0), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4], 'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4, 5],
#                          'n_estimators': [10, 30, 50]},
#              scoring='accuracy')

# %%
best_params_RF = gridSearch_RF.best_params_
best_params_RF
# Out:
# {'bootstrap': False,
#  'criterion': 'entropy',
#  'max_depth': 4,
#  'min_samples_leaf': 1,
#  'min_samples_split': 5,
#  'n_estimators': 30}

# %%
best_RF = RandomForestClassifier(random_state=42, **best_params_RF)
best_RF.fit(X_train_Smote, y_train_Smote)
# Out:
# RandomForestClassifier(bootstrap=False, criterion='entropy', max_depth=4,
#                        min_samples_split=5, n_estimators=30, random_state=42)

# %% [markdown]
# #  <b> • RF Model Evaluation:

# %%
# Evaluate the optimized model on the train data
print(classification_report(y_train, best_RF.predict(x_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.98      0.85      1417
#            1       0.94      0.50      0.65       876
#
#     accuracy                           0.79      2293
#    macro avg       0.85      0.74      0.75      2293
# weighted avg       0.83      0.79      0.78      2293

# %%
# Evaluate the optimized model on the test data
print(classification_report(y_test, best_RF.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.96      0.82       581
#            1       0.89      0.46      0.61       402
#
#     accuracy                           0.76       983
#    macro avg       0.81      0.71      0.72       983
# weighted avg       0.79      0.76      0.74       983

# %%
# Confusion Metrics
confusion_RF = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, best_RF.predict(x_test)))
confusion_RF.plot()

# %% [markdown]
# # <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:120%; text-align:center; border-radius:1000px 1000px;">↪  Step 9  :  SVM Model Building :</p>

# %% [markdown]
# #  <b> • SVM Base Model:

# %%
# Define the SVM base model
base_SVM = SVC()

# %% [markdown]
# #  <b> • SVM Hyperparameter Tuning:

# %%
# Define the SVM hyperparameter
param_grid_SVM = {
    'C': [0.1, 1],  # Regularization parameter: higher values prioritize fitting the training data, while lower values apply more regularization to avoid overfitting.
    'gamma': [0.1, 1],  # Kernel coefficient for 'rbf' kernel: controls the influence of individual training examples, with higher values leading to more complex models.
    'kernel': ['linear']  # Kernel type: 'rbf' for non-linear classification, 'linear' for linear decision boundaries.
}

# %%
best_svm = SVC()
best_svm.fit(X_train_Smote, y_train_Smote)
# Out:
# SVC()

# %% [markdown]
# #  <b> • SVM Model Evaluation:

# %%
# Evaluate the optimized model on the train data
print(classification_report(y_train, best_svm.predict(x_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.76      1417
#            1       0.00      0.00      0.00       876
#
#     accuracy                           0.62      2293
#    macro avg       0.31      0.50      0.38      2293
# weighted avg       0.38      0.62      0.47      2293

# %%
# Evaluate the optimized model on the test data
print(classification_report(y_test, best_svm.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      1.00      0.74       581
#            1       0.00      0.00      0.00       402
#
#     accuracy                           0.59       983
#    macro avg       0.30      0.50      0.37       983
# weighted avg       0.35      0.59      0.44       983

# %%
# Confusion Metrics
confusion_svm = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, best_svm.predict(x_test)))
confusion_svm.plot()

# %% [markdown]
# # <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:120%; text-align:center; border-radius:1000px 1000px;">↪  Step 10  :  KNN Model Building :</p>

# %% [markdown]
# #  <b> • KNN Base Model:

# %%
# Define the KNN base model
knn = KNeighborsClassifier()

# %% [markdown]
# #  <b> • KNN Hyperparameter Tuning:

# %%
# Define the KNN hyperparameter
param_grid_knn = {
    'n_neighbors': [3, 5, 7, 9],  # Number of neighbors: determines how many neighbors to consider when classifying a point.
    'weights': ['uniform', 'distance'],  # Weight function: 'uniform' gives all neighbors equal weight, while 'distance' weighs closer neighbors more.
    'metric': ['euclidean', 'manhattan', 'minkowski']  # Distance metric: 'euclidean' is standard straight-line distance, 'manhattan' is sum of absolute differences, and 'minkowski' is a generalized distance metric.
}

# %%
gridsearch_knn = GridSearchCV(estimator=knn, param_grid=param_grid_knn, refit=True)
gridsearch_knn.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']})

# %%
best_params_knn = gridsearch_knn.best_params_

print(best_params_knn)
# Out:
# {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'distance'}

# %%
best_knn = KNeighborsClassifier(**best_params_knn)

# Fit the re-initialized model on the training data
best_knn.fit(X_train_Smote, y_train_Smote)
# Out:
# KNeighborsClassifier(metric='manhattan', n_neighbors=9, weights='distance')

# %% [markdown]
# #  <b> • KNN Model Evaluation:

# %%
# Evaluate the optimized model on the train data
print(classification_report(y_train, best_knn.predict(x_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1417
#            1       1.00      1.00      1.00       876
#
#     accuracy                           1.00      2293
#    macro avg       1.00      1.00      1.00      2293
# weighted avg       1.00      1.00      1.00      2293

# %%
# Evaluate the optimized model on the test data
print(classification_report(y_test, best_knn.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.74      0.66       581
#            1       0.43      0.28      0.34       402
#
#     accuracy                           0.55       983
#    macro avg       0.51      0.51      0.50       983
# weighted avg       0.53      0.55      0.53       983

# %%
# Confusion Metrics
confusion_KNN = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, best_knn.predict(x_test)))
confusion_KNN.plot()

# %% [markdown]
# # <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:120%; text-align:center; border-radius:1000px 1000px;">↪  Step 8  :  XGBoost Model Building :</p>

# %% [markdown]
# #  <b> • XGBoost Base Model:

# %%
from xgboost import XGBClassifier

#creating the model
model_xgb=XGBClassifier(max_depth=8,n_estimators=125,random_state=0,learning_rate=0.03,n_jobs=5)

#training the model
model_xgb.fit(X_train_Smote,y_train_Smote)

#making the prediction
pred_xgb=model_xgb.predict(x_test)

# %% [markdown]
# #  <b> • XGBoost Model Evaluation:

# %%
print(classification_report(y_train, model_xgb.predict(x_train)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      1417
#            1       0.98      0.92      0.95       876
#
#     accuracy                           0.96      2293
#    macro avg       0.96      0.95      0.96      2293
# weighted avg       0.96      0.96      0.96      2293

# %%
print(classification_report(y_test, pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81       581
#            1       0.74      0.67      0.71       402
#
#     accuracy                           0.77       983
#    macro avg       0.77      0.76      0.76       983
# weighted avg       0.77      0.77      0.77       983

# %%
# Confusion Metrics
confusion_XGB = metrics.ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test, pred_xgb))
confusion_XGB.plot()

# %% [markdown]
# # <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:120%; text-align:center; border-radius:1000px 1000px;">↪  Step 11  :  Comparison Of All Algorithms :</p>

# %% [markdown]
# <div style="background-color: #975455; padding: 25px; border-radius: 50px; width:85%;">
#     <table style="width: 95%; background-color: #dbdbd9; border: 3px solid black; color: black; border-collapse: collapse;">
#         <tr>
#             <th style="border: 3px solid black; padding: 8px; font-family: 'Verdana';">Algorithm</th>
#             <th style="border: 3px solid black; padding: 8px; font-family: 'Verdana';">Training Accuracy</th>
#             <th style="border: 3px solid black; padding: 8px; font-family: 'Verdana';">Testing Accuracy</th>
#             <th style="border: 3px solid black; padding: 8px; font-family: 'Verdana';">Testing Precision</th>
#             <th style="border: 3px solid black; padding: 8px; font-family: 'Verdana';">Testing Recall</th>
#             <th style="border: 3px solid black; padding: 8px; font-family: 'Verdana';">Testing F1-Score</th>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Logistic Regression</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.62</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.60</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">1.00</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.01</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.02</td>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Decision Tree</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.72</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.73</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.73</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.53</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.61</td>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">Random Forest</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.79</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.76</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.89</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.46</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.61</td>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">SVM</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.62</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.59</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.00</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.00</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.00</td>
#         </tr>
#         <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">KNN</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">1.00</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.55</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.43</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.28</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.34</td>
#             </tr>
#             <tr>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%">XGBoost</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.96</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.77</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.74</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.67</td>
#             <td style="border: 3px solid black; padding: 8px; font-family: 'bahnschrift'; font-size:110%; text-align:center">0.71</td>
#         </tr>
#     </table>
# </div>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #975455; font-size:115%; text-align:left; width: 90%;">
# <h2 align="left"><font color="White" style="font-family: 'Book Antiqua';">Result:</font></h2>
#
# <h3 align="left"><font color="White" style="font-family: 'Book Antiqua';">Best Model : Random Forest</font></h3>
#
# <p align="left"><font color="White" style="font-family: 'Book Antiqua';">
#
# * __Reason:__
#     - Random Forest achieved a testing accuracy of 0.76, which is higher than most other models except XGBoost (which has an accuracy of 0.77).
#     - Random Forest has a good balance between testing precision (0.89) and recall (0.46).
# </font></p>
#
# <h3 align="left"><font color="White" style="font-family: 'Book Antiqua';">Why Other Models Are Not Best:</font></h3>
#
# <p align="left"><font color="White" style="font-family: 'Book Antiqua';">
#
# * __Logistic Regression and SVM:__
#     - Both Logistic Regression and SVM have significantly lower scores across all testing metrics (accuracy, precision, recall, and F1-score).
#     - These models may not generalize well to unseen data.
# * __Decision Tree:__
#     - Decision Tree has a higher training accuracy but lower testing accuracy compared to Random Forest.
#     - This discrepancy suggests overfitting—the model performs well on the training data but poorly on unseen data.
# * __KNN:__
#     - KNN has perfect training accuracy but poor testing metrics (precision, recall, and F1-score).
#     - Again, this indicates overfitting, as the model memorizes the training data rather than learning general patterns.
# * __XGBoost:__
#     - XGBoost has slightly better accuracy (0.77) than Random Forest (0.76).
#     - However, its precision (0.89) is slightly lower than Random Forest, which may impact its performance in specific scenarios.
# </font></p>

# %% [markdown]
# # <p style="background-color:#6b5c5c; font-family:Book Antiqua; color:white; font-size:120%; text-align:center; border-radius:1000px 1000px;">↪  Step 12  :  Conclusion :</p>

# %% [markdown]
# <div style="border-radius:10px; padding: 15px; background-color: #975455; font-family:Book Antiqua; font-size:115%; text-align: justify; width: 95%;">
# <h2 align="left"><font color="White" style="font-family: 'Book Antiqua';">In this project,</font></h2>
# <p align="left"><font color="White" style="font-family: 'Book Antiqua';">Various machine learning algorithms were applied to predict water potability based on the given dataset. The models tested include Logistic Regression, Decision Tree, Random Forest, SVM, KNN and XGBoost. Among these, the Random Forest classifier demonstrated the highest performance in terms of accuracy and robustness. This suggests that Random Forest is particularly effective in capturing the complex relationships within the data, making it a suitable choice for this classification task. The superior performance of Random Forest highlights its capability to handle the nuances of water quality prediction, which could be vital for ensuring safe and reliable water sources.
#
# Future work could explore further optimization of the Random Forest model or the integration of additional features to enhance predictive accuracy.</font></p>
